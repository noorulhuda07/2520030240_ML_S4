# %%
# 1. IMPORT LIBRARIES


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import files
import zipfile
import os

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# 2. UPLOAD DATASET ZIP


uploaded = files.upload()

print("\nUploaded file(s):")
for filename in uploaded.keys():
    print(filename)
# Out:
#      <input type="file" id="files-f8d9b720-817b-419b-b4d4-91c19f2e8d0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8d9b720-817b-419b-b4d4-91c19f2e8d0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 3. EXTRACT ZIP FILE


zip_file = list(uploaded.keys())[0]

extract_folder = "dataset"

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

print("ZIP file extracted successfully!")
# Out:
# ZIP file extracted successfully!

# %%
# 4. FIND FILES INSIDE ZIP


for root, dirs, files_list in os.walk(extract_folder):
    for file in files_list:
        print(os.path.join(root, file))
# Out:
# dataset/phishing_features.csv

# %%
# 5. LOAD CSV FILE


csv_files = []

for root, dirs, files_list in os.walk(extract_folder):
    for file in files_list:
        if file.lower().endswith(".csv"):
            csv_files.append(os.path.join(root, file))

print("CSV files found:")
for file in csv_files:
    print(file)

if len(csv_files) == 0:
    raise FileNotFoundError("No CSV file found inside the ZIP.")

# Load the first CSV
csv_path = csv_files[0]

df = pd.read_csv(csv_path)

print("\nDataset loaded successfully!")
print("File:", csv_path)
# Out:
# CSV files found:
# dataset/phishing_features.csv
#
# Dataset loaded successfully!
# File: dataset/phishing_features.csv

# %%
# 6. FIRST 5 ROWS


df.head()
# Out:
#                                                  url  label  url_length  \
# 0  http://forum.uk.securebankinggroup.com/107519/...      1          89
# 1                          http://b45042.com/fish/29      1          25
# 2                     http://bet73018.com/lottery/99      1          30
# 3            https://logiin--metsa-autho.webflow.io/      1          39
# 4              https://mettamasklogiiann.webflow.io/      1          37
#
#    num_dots  has_https  has_ip  num_subdirs  num_params  suspicious_words  \
# 0         3          0       0            5           0                 2
# 1         1          0       0            4           0                 0
# 2         1          0       0            4           0                 0
# 3         2          1       0            3           0                 0
# 4         2          1       0            3           0                 0
#
#    tld  special_char_count  digits_count   entropy
# ...

# %%
# 7. LAST 5 ROWS


df.tail()
# Out:
#                        url  label  url_length  num_dots  has_https  has_ip  \
# 160059   safeexample96.net      0          17         1          0       0
# 160060   safeexample97.net      0          17         1          0       0
# 160061   safeexample98.net      0          17         1          0       0
# 160062   safeexample99.net      0          17         1          0       0
# 160063  safeexample100.net      0          18         1          0       0
#
#         num_subdirs  num_params  suspicious_words  tld  special_char_count  \
# 160059            0           0                 0  NaN                   0
# 160060            0           0                 0  NaN                   0
# 160061            0           0                 0  NaN                   0
# 160062            0           0                 0  NaN                   0
# 160063            0           0                 0  NaN                   0
#
#         digits_count   entropy
# 160059             2  3.499228
# ...

# %%
# 8. RANDOM SAMPLE

df.sample(5)
# Out:
#                                                       url  label  url_length  \
# 9317                        http://175.148.79.233:37335/i      1          29
# 150652  https://new.express.adobe.com/webpage/EUBirjGt...      1          51
# 130284                        https://zpr.io/PFgLMFj8dcwp      1          27
# 20520                   http://200.59.83.111:49203/bin.sh      1          33
# 54288   http://colis-nouvellelivraison-france.com/bins...      1          86
#
#         num_dots  has_https  has_ip  num_subdirs  num_params  \
# 9317           3          0       1            3           0
# 150652         3          1       0            4           0
# 130284         1          1       0            3           0
# 20520          4          0       1            3           0
# 54288          2          0       0            4           0
#
#         suspicious_words  tld  special_char_count  digits_count   entropy
# ...

# %%
# 9. DATASET SHAPE


rows, columns = df.shape

print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 160064
# Number of columns: 13

# %%
# 10. COLUMN NAMES


print("Columns in dataset:\n")

for i, column in enumerate(df.columns, 1):
    print(i, "->", column)
# Out:
# Columns in dataset:
#
# 1 -> url
# 2 -> label
# 3 -> url_length
# 4 -> num_dots
# 5 -> has_https
# 6 -> has_ip
# 7 -> num_subdirs
# 8 -> num_params
# 9 -> suspicious_words
# 10 -> tld
# 11 -> special_char_count
# 12 -> digits_count
# 13 -> entropy

# %%
# 11. DATASET INFORMATION


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160064 entries, 0 to 160063
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   url                 160064 non-null  object
#  1   label               160064 non-null  int64
#  2   url_length          160064 non-null  int64
#  3   num_dots            160064 non-null  int64
#  4   has_https           160064 non-null  int64
#  5   has_ip              160064 non-null  int64
#  6   num_subdirs         160064 non-null  int64
#  7   num_params          160064 non-null  int64
#  8   suspicious_words    160064 non-null  int64
#  9   tld                 159243 non-null  object
#  10  special_char_count  160064 non-null  int64
#  11  digits_count        160064 non-null  int64
#  12  entropy             160064 non-null  float64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.9+ MB

# %%
# 12. DATASET INFORMATION


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160064 entries, 0 to 160063
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   url                 160064 non-null  object
#  1   label               160064 non-null  int64
#  2   url_length          160064 non-null  int64
#  3   num_dots            160064 non-null  int64
#  4   has_https           160064 non-null  int64
#  5   has_ip              160064 non-null  int64
#  6   num_subdirs         160064 non-null  int64
#  7   num_params          160064 non-null  int64
#  8   suspicious_words    160064 non-null  int64
#  9   tld                 159243 non-null  object
#  10  special_char_count  160064 non-null  int64
#  11  digits_count        160064 non-null  int64
#  12  entropy             160064 non-null  float64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.9+ MB

# %%
# 13. STATISTICAL SUMMARY


df.describe()
# Out:
#                label     url_length       num_dots      has_https  \
# count  160064.000000  160064.000000  160064.000000  160064.000000
# mean        0.994877      55.107382       2.998963       0.434089
# std         0.071391     101.782469       1.119210       0.495638
# min         0.000000       6.000000       1.000000       0.000000
# 25%         1.000000      30.000000       2.000000       0.000000
# 50%         1.000000      37.000000       3.000000       0.000000
# 75%         1.000000      65.000000       4.000000       1.000000
# max         1.000000   25523.000000      59.000000       1.000000
#
#               has_ip    num_subdirs     num_params  suspicious_words  \
# count  160064.000000  160064.000000  160064.000000     160064.000000
# mean        0.485475       4.128436       0.221499          0.023809
# std         0.499791       2.090180       0.935608          0.168235
# min         0.000000       0.000000       0.000000          0.000000
# ...

# %%
df.describe(include='all')
# Out:
#                       url          label     url_length       num_dots  \
# count              160064  160064.000000  160064.000000  160064.000000
# unique             160064            NaN            NaN            NaN
# top     safeexample84.net            NaN            NaN            NaN
# freq                    1            NaN            NaN            NaN
# mean                  NaN       0.994877      55.107382       2.998963
# std                   NaN       0.071391     101.782469       1.119210
# min                   NaN       0.000000       6.000000       1.000000
# 25%                   NaN       1.000000      30.000000       2.000000
# 50%                   NaN       1.000000      37.000000       3.000000
# 75%                   NaN       1.000000      65.000000       4.000000
# max                   NaN       1.000000   25523.000000      59.000000
#
#             has_https         has_ip    num_subdirs     num_params  \
# ...

# %%
# 14. MISSING VALUES


missing_values = df.isnull().sum()

print("Missing values in each column:\n")
print(missing_values)
# Out:
# Missing values in each column:
#
# url                     0
# label                   0
# url_length              0
# num_dots                0
# has_https               0
# has_ip                  0
# num_subdirs             0
# num_params              0
# suspicious_words        0
# tld                   821
# special_char_count      0
# digits_count            0
# entropy                 0
# dtype: int64

# %%
# Missing value percentage

missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_table = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': missing_percentage
})

missing_table
# Out:
#                     Missing Values  Percentage
# url                              0     0.00000
# label                            0     0.00000
# url_length                       0     0.00000
# num_dots                         0     0.00000
# has_https                        0     0.00000
# has_ip                           0     0.00000
# num_subdirs                      0     0.00000
# num_params                       0     0.00000
# suspicious_words                 0     0.00000
# tld                            821     0.51292
# special_char_count               0     0.00000
# digits_count                     0     0.00000
# entropy                          0     0.00000

# %%
# 15. DUPLICATE ROWS


duplicate_rows = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_rows)
# Out:
# Number of duplicate rows: 0

# %%
# 16. DUPLICATE URLS

if 'url' in df.columns:
    duplicate_urls = df['url'].duplicated().sum()
    print("Number of duplicate URLs:", duplicate_urls)
else:
    print("'url' column not found.")
# Out:
# Number of duplicate URLs: 0

# %%
# 17. UNIQUE VALUES


unique_values = df.nunique().sort_values()

unique_values
# Out:
# label                      2
# has_https                  2
# has_ip                     2
# suspicious_words           4
# num_dots                  19
# num_params                23
# num_subdirs               24
# special_char_count        74
# digits_count             180
# url_length               521
# tld                      535
# entropy                43046
# url                   160064
# dtype: int64

# %%
# 18. TARGET VARIABLE


print(df['label'].value_counts())
# Out:
# label
# 1    159244
# 0       820
# Name: count, dtype: int64

# %%
label_percentage = df['label'].value_counts(normalize=True) * 100

print(label_percentage)
# Out:
# label
# 1    99.487705
# 0     0.512295
# Name: proportion, dtype: float64

# %%
# 19. TARGET DISTRIBUTION


label_counts = df['label'].value_counts().sort_index()

plt.figure(figsize=(7, 5))

plt.bar(
    ['Legitimate (0)', 'Phishing (1)'],
    label_counts.values
)

plt.title('Distribution of Legitimate and Phishing URLs')
plt.xlabel('URL Class')
plt.ylabel('Number of URLs')

plt.show()

# %%
# 20. TARGET PIE CHART


labels = ['Legitimate (0)', 'Phishing (1)']

plt.figure(figsize=(7, 7))

plt.pie(
    label_counts.values,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Phishing vs Legitimate URLs')

plt.show()

# %%
# 21. NUMERICAL COLUMNS


numeric_columns = df.select_dtypes(include=np.number).columns.tolist()

print("Numerical columns:")
print(numeric_columns)
# Out:
# Numerical columns:
# ['label', 'url_length', 'num_dots', 'has_https', 'has_ip', 'num_subdirs', 'num_params', 'suspicious_words', 'special_char_count', 'digits_count', 'entropy']

# %%
# 22. CATEGORICAL COLUMNS


categorical_columns = df.select_dtypes(
    include=['object', 'category']
).columns.tolist()

print("Categorical columns:")
print(categorical_columns)
# Out:
# Categorical columns:
# ['url', 'tld']

# %%
# 23. NUMERICAL FEATURE DISTRIBUTIONS


for column in numeric_columns:

    if column == 'label':
        continue

    plt.figure(figsize=(8, 5))

    plt.hist(df[column].dropna(), bins=30)

    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

    plt.show()

# %%
# 24. URL LENGTH DISTRIBUTION


if 'url_length' in df.columns:

    plt.figure(figsize=(9, 5))

    plt.hist(
        df['url_length'].dropna(),
        bins=50
    )

    plt.title('Distribution of URL Length')
    plt.xlabel('URL Length')
    plt.ylabel('Frequency')

    plt.show()

# %%
# 25. URL LENGTH BY CLASS


if 'url_length' in df.columns:

    legitimate = df[df['label'] == 0]['url_length']
    phishing = df[df['label'] == 1]['url_length']

    plt.figure(figsize=(9, 5))

    plt.hist(
        legitimate.dropna(),
        bins=40,
        alpha=0.6,
        label='Legitimate'
    )

    plt.hist(
        phishing.dropna(),
        bins=40,
        alpha=0.6,
        label='Phishing'
    )

    plt.title('URL Length: Legitimate vs Phishing')
    plt.xlabel('URL Length')
    plt.ylabel('Frequency')
    plt.legend()

    plt.show()

# %%
# 26. FEATURE MEANS BY CLASS


feature_means = df.groupby('label')[numeric_columns].mean()

feature_means
# Out:
#        label  url_length  num_dots  has_https    has_ip  num_subdirs  \
# label
# 0        0.0   14.078049  1.035366   0.000000  0.000000     0.000000
# 1        1.0   55.318656  3.009074   0.436324  0.487974     4.149695
#
#        num_params  suspicious_words  special_char_count  digits_count  \
# label
# 0        0.000000          0.003659            0.004878      1.086585
# 1        0.222639          0.023913            1.503121     12.797028
#
#         entropy
# label
# 0      3.355376
# 1      4.250687

# %%
feature_means.T
# Out:
# label                       0          1
# label                0.000000   1.000000
# url_length          14.078049  55.318656
# num_dots             1.035366   3.009074
# has_https            0.000000   0.436324
# has_ip               0.000000   0.487974
# num_subdirs          0.000000   4.149695
# num_params           0.000000   0.222639
# suspicious_words     0.003659   0.023913
# special_char_count   0.004878   1.503121
# digits_count         1.086585  12.797028
# entropy              3.355376   4.250687

# %%
# 27. BOXPLOTS


for column in numeric_columns:

    # Skip target variable
    if column == 'label':
        continue

    # Get values for each class
    data_0 = df[df['label'] == 0][column].dropna()
    data_1 = df[df['label'] == 1][column].dropna()

    # Create figure
    plt.figure(figsize=(8, 5))

    # Create boxplot
    plt.boxplot(
        [data_0, data_1],
        tick_labels=['Legitimate', 'Phishing']
    )

    # Titles and labels
    plt.title(f'{column}: Legitimate vs Phishing')
    plt.xlabel('URL Class')
    plt.ylabel(column)

    # Display
    plt.show()

# %%
# 28. HTTPS ANALYSIS


if 'has_https' in df.columns:

    https_table = pd.crosstab(
        df['has_https'],
        df['label']
    )

    print(https_table)
# Out:
# label        0      1
# has_https
# 0          820  89762
# 1            0  69482

# %%
#GRAPH
if 'has_https' in df.columns:

    https_counts = pd.crosstab(
        df['has_https'],
        df['label']
    )

    https_counts.plot(
        kind='bar',
        figsize=(8, 5)
    )

    plt.title('HTTPS Usage by URL Class')
    plt.xlabel('HTTPS (0 = No, 1 = Yes)')
    plt.ylabel('Number of URLs')

    plt.xticks(rotation=0)

    plt.show()

# %%
# ============================================
# 29. IP ADDRESS ANALYSIS
# ============================================

if 'has_ip' in df.columns:

    ip_counts = pd.crosstab(
        df['has_ip'],
        df['label']
    )

    print(ip_counts)

    ip_counts.plot(
        kind='bar',
        figsize=(8, 5)
    )

    plt.title('IP Address Usage by URL Class')
    plt.xlabel('Contains IP Address (0 = No, 1 = Yes)')
    plt.ylabel('Number of URLs')

    plt.xticks(rotation=0)

    plt.show()
# Out:
# label     0      1
# has_ip
# 0       820  81537
# 1         0  77707

# %%
# ============================================
# 30. SUSPICIOUS WORDS ANALYSIS
# ============================================

if 'suspicious_words' in df.columns:

    suspicious_means = df.groupby('label')['suspicious_words'].mean()

    print(suspicious_means)

    plt.figure(figsize=(8, 5))

    plt.boxplot(
        [
            df[df['label'] == 0]['suspicious_words'].dropna(),
            df[df['label'] == 1]['suspicious_words'].dropna()
        ],
        labels=['Legitimate', 'Phishing']
    )

    plt.title('Suspicious Words: Legitimate vs Phishing')
    plt.xlabel('URL Class')
    plt.ylabel('Number of Suspicious Words')

    plt.show()
# Out:
# label
# 0    0.003659
# 1    0.023913
# Name: suspicious_words, dtype: float64
# /tmp/ipykernel_10458/1718182646.py:13: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
# ============================================
# 31. DIGITS ANALYSIS
# ============================================

if 'digits_count' in df.columns:

    plt.figure(figsize=(8, 5))

    plt.boxplot(
        [
            df[df['label'] == 0]['digits_count'].dropna(),
            df[df['label'] == 1]['digits_count'].dropna()
        ],
        labels=['Legitimate', 'Phishing']
    )

    plt.title('Number of Digits: Legitimate vs Phishing')
    plt.xlabel('URL Class')
    plt.ylabel('Number of Digits')

    plt.show()
# Out:
# /tmp/ipykernel_10458/221740126.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
# ============================================
# 32. SPECIAL CHARACTER ANALYSIS
# ============================================

if 'special_char_count' in df.columns:

    plt.figure(figsize=(8, 5))

    plt.boxplot(
        [
            df[df['label'] == 0]['special_char_count'].dropna(),
            df[df['label'] == 1]['special_char_count'].dropna()
        ],
        labels=['Legitimate', 'Phishing']
    )

    plt.title('Special Characters: Legitimate vs Phishing')
    plt.xlabel('URL Class')
    plt.ylabel('Special Character Count')

    plt.show()
# Out:
# /tmp/ipykernel_10458/27377883.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
# ============================================
# 33. ENTROPY ANALYSIS
# ============================================

if 'entropy' in df.columns:

    plt.figure(figsize=(8, 5))

    plt.hist(
        df[df['label'] == 0]['entropy'].dropna(),
        bins=40,
        alpha=0.6,
        label='Legitimate'
    )

    plt.hist(
        df[df['label'] == 1]['entropy'].dropna(),
        bins=40,
        alpha=0.6,
        label='Phishing'
    )

    plt.title('URL Entropy: Legitimate vs Phishing')
    plt.xlabel('Entropy')
    plt.ylabel('Frequency')
    plt.legend()

    plt.show()

# %%
# ============================================
# 34. TLD ANALYSIS
# ============================================

if 'tld' in df.columns:

    print("Top 20 TLDs:")

    print(
        df['tld']
        .value_counts()
        .head(20)
    )
# Out:
# Top 20 TLDs:
# tld
# com       32341
# ru        15011
# 202        3745
# 34         3551
# 227        3312
# de         2782
# app        2758
# dev        2691
# me         2549
# 228        2262
# 232        2262
# ly         2185
# to         2036
# page       1941
# 199        1876
# info       1428
# online     1328
# io         1197
# org        1142
# 189        1139
# Name: count, dtype: int64

# %%
#GRAPH
if 'tld' in df.columns:

    top_tlds = df['tld'].value_counts().head(15)

    plt.figure(figsize=(10, 6))

    plt.bar(
        top_tlds.index.astype(str),
        top_tlds.values
    )

    plt.title('Top 15 Most Common TLDs')
    plt.xlabel('TLD')
    plt.ylabel('Number of URLs')

    plt.xticks(rotation=45)

    plt.show()

# %%
# ============================================
# 35. TLD VS PHISHING
# ============================================

if 'tld' in df.columns:

    tld_label = pd.crosstab(
        df['tld'],
        df['label']
    )

    print(tld_label.head(20))
# Out:
# label    1
# tld
# 0       93
# 0x31     1
# 1      121
# 10     271
# 100    187
# 101    302
# 102    198
# 103    232
# 104    218
# 105    186
# 106    193
# 107    177
# 108    176
# 109    300
# 11     163
# 110    233
# 111    292
# 112    170
# 113    220
# 114    293

# %%
#Phishing percentage by TLD:
if 'tld' in df.columns:

    tld_phishing_rate = (
        df.groupby('tld')['label']
        .mean()
        .sort_values(ascending=False)
    )

    print(
        tld_phishing_rate.head(20)
    )
# Out:
# tld
# zw      1.0
# 0       1.0
# 0x31    1.0
# 1       1.0
# 10      1.0
# 100     1.0
# 101     1.0
# vn      1.0
# vip     1.0
# vg      1.0
# vc      1.0
# uz      1.0
# uy      1.0
# us      1.0
# uk      1.0
# ua      1.0
# tz      1.0
# tw      1.0
# tv      1.0
# tr      1.0
# Name: label, dtype: float64

# %%
# ============================================
# 36. CORRELATION MATRIX
# ============================================

correlation = df[numeric_columns].corr()

plt.figure(figsize=(12, 9))

plt.imshow(
    correlation,
    aspect='auto'
)

plt.colorbar()

plt.xticks(
    range(len(correlation.columns)),
    correlation.columns,
    rotation=90
)

plt.yticks(
    range(len(correlation.columns)),
    correlation.columns
)

plt.title('Correlation Matrix of Numerical Features')

plt.tight_layout()

plt.show()

# %%
# ============================================
# 37. CORRELATION WITH TARGET
# ============================================

target_correlation = (
    df[numeric_columns]
    .corr()['label']
    .sort_values(ascending=False)
)

print(target_correlation)
# Out:
# label                 1.000000
# num_subdirs           0.141735
# entropy               0.133363
# num_dots              0.125898
# has_ip                0.069704
# has_https             0.062848
# digits_count          0.047991
# url_length            0.028927
# special_char_count    0.028911
# num_params            0.016988
# suspicious_words      0.008595
# Name: label, dtype: float64

# %%
# ============================================
# 38. FEATURE CORRELATION RANKING
# ============================================

target_corr = (
    df[numeric_columns]
    .corr()['label']
    .drop('label')
    .sort_values(key=abs, ascending=False)
)

target_corr
# Out:
# num_subdirs           0.141735
# entropy               0.133363
# num_dots              0.125898
# has_ip                0.069704
# has_https             0.062848
# digits_count          0.047991
# url_length            0.028927
# special_char_count    0.028911
# num_params            0.016988
# suspicious_words      0.008595
# Name: label, dtype: float64

# %%
# ============================================
# 39. OUTLIER DETECTION USING IQR
# ============================================

outlier_summary = []

for column in numeric_columns:

    if column == 'label':
        continue

    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[
        (df[column] < lower_bound) |
        (df[column] > upper_bound)
    ]

    outlier_summary.append({
        'Feature': column,
        'Q1': Q1,
        'Q3': Q3,
        'IQR': IQR,
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound,
        'Number of Outliers': len(outliers),
        'Outlier Percentage': (len(outliers) / len(df)) * 100
    })

outlier_df = pd.DataFrame(outlier_summary)

outlier_df
# Out:
#               Feature         Q1        Q3        IQR  Lower Bound  \
# 0          url_length  30.000000  65.00000  35.000000    -22.50000
# 1            num_dots   2.000000   4.00000   2.000000     -1.00000
# 2           has_https   0.000000   1.00000   1.000000     -1.50000
# 3              has_ip   0.000000   1.00000   1.000000     -1.50000
# 4         num_subdirs   3.000000   4.00000   1.000000      1.50000
# 5          num_params   0.000000   0.00000   0.000000      0.00000
# 6    suspicious_words   0.000000   0.00000   0.000000      0.00000
# 7  special_char_count   0.000000   1.00000   1.000000     -1.50000
# 8        digits_count   3.000000  16.00000  13.000000    -16.50000
# 9             entropy   3.907734   4.48485   0.577116      3.04206
#
#    Upper Bound  Number of Outliers  Outlier Percentage
# 0   117.500000               12907            8.063650
# 1     7.000000                 331            0.206792
# 2     2.500000                   0            0.000000
# ...

# %%
# ============================================
# 40. RANDOM FOREST FEATURE IMPORTANCE
# OPTIONAL - MODELING PREVIEW
# ============================================

from sklearn.ensemble import RandomForestClassifier

# Select numerical features except target
features = [
    col for col in numeric_columns
    if col != 'label'
]

X = df[features].copy()
y = df['label']

# Handle missing values for this preview
X = X.fillna(X.median())

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X, y)

importance = pd.DataFrame({
    'Feature': features,
    'Importance': rf.feature_importances_
})

importance = importance.sort_values(
    'Importance',
    ascending=False
)

importance
# Out:
#               Feature  Importance
# 4         num_subdirs    0.502277
# 0          url_length    0.409677
# 9             entropy    0.061121
# 1            num_dots    0.009422
# 2           has_https    0.009089
# 8        digits_count    0.006206
# 3              has_ip    0.001201
# 7  special_char_count    0.001001
# 5          num_params    0.000005
# 6    suspicious_words    0.000001

# %%
#GRAPH
plt.figure(figsize=(10, 6))

plt.barh(
    importance['Feature'],
    importance['Importance']
)

plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Random Forest Feature Importance')

plt.gca().invert_yaxis()

plt.show()

# %%
# ============================================
# 41. URL LENGTH VS NUMBER OF DOTS
# ============================================

if 'url_length' in df.columns and 'num_dots' in df.columns:

    plt.figure(figsize=(9, 6))

    plt.scatter(
        df['url_length'],
        df['num_dots'],
        alpha=0.3
    )

    plt.xlabel('URL Length')
    plt.ylabel('Number of Dots')
    plt.title('URL Length vs Number of Dots')

    plt.show()

# %%
# ============================================
# 42. URL LENGTH VS ENTROPY
# ============================================

if 'url_length' in df.columns and 'entropy' in df.columns:

    plt.figure(figsize=(9, 6))

    plt.scatter(
        df['url_length'],
        df['entropy'],
        alpha=0.3
    )

    plt.xlabel('URL Length')
    plt.ylabel('Entropy')
    plt.title('URL Length vs Entropy')

    plt.show()

# %%
# ============================================
# 43. PHISHING RATE FOR BINARY FEATURES
# ============================================

binary_features = [
    col for col in numeric_columns
    if col != 'label' and df[col].nunique() <= 2
]

for column in binary_features:

    rate = df.groupby(column)['label'].mean() * 100

    print("\n", column)
    print(rate)
# Out:
#  has_https
# has_https
# 0     99.094743
# 1    100.000000
# Name: label, dtype: float64
#
#  has_ip
# has_ip
# 0     99.004335
# 1    100.000000
# Name: label, dtype: float64

# %%
# ============================================
# 44. FINAL DATA QUALITY REPORT
# ============================================

print("=" * 50)
print("FINAL DATASET QUALITY REPORT")
print("=" * 50)

print("\nDataset shape:")
print(df.shape)

print("\nMissing values:")
print(df.isnull().sum().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())

if 'url' in df.columns:
    print("\nDuplicate URLs:")
    print(df['url'].duplicated().sum())

print("\nNumerical columns:")
print(numeric_columns)

print("\nCategorical columns:")
print(categorical_columns)

print("\nTarget distribution:")
print(df['label'].value_counts())

print("\nTarget percentages:")
print(df['label'].value_counts(normalize=True) * 100)
# Out:
# ...
# FINAL DATASET QUALITY REPORT
# ...
#
# Dataset shape:
# (160064, 13)
#
# Missing values:
# 821
#
# Duplicate rows:
# 0
#
# Duplicate URLs:
# 0
#
# Numerical columns:
# ['label', 'url_length', 'num_dots', 'has_https', 'has_ip', 'num_subdirs', 'num_params', 'suspicious_words', 'special_char_count', 'digits_count', 'entropy']
#
# Categorical columns:
# ['url', 'tld']
#
# Target distribution:
# label
# 1    159244
# 0       820
# Name: count, dtype: int64
#
# Target percentages:
# label
# 1    99.487705
# 0     0.512295
# Name: proportion, dtype: float64

# %%
# ============================================
# 45. EDA SUMMARY
# ============================================

print("=" * 60)
print("EDA SUMMARY")
print("=" * 60)

print(f"\nTotal observations: {df.shape[0]}")
print(f"Total features: {df.shape[1]}")

print(f"\nMissing values: {df.isnull().sum().sum()}")

print(f"Duplicate rows: {df.duplicated().sum()}")

if 'url' in df.columns:
    print(f"Duplicate URLs: {df['url'].duplicated().sum()}")

print("\nClass distribution:")

for label, count in df['label'].value_counts().sort_index().items():

    percentage = (count / len(df)) * 100

    if label == 0:
        name = "Legitimate"
    else:
        name = "Phishing"

    print(
        f"{name}: {count} ({percentage:.2f}%)"
    )

print("\nNumerical features:")
print(len(numeric_columns))

print("\nCategorical features:")
print(len(categorical_columns))

print("\nEDA completed successfully!")
# Out:
# ...
# EDA SUMMARY
# ...
#
# Total observations: 160064
# Total features: 13
#
# Missing values: 821
# Duplicate rows: 0
# Duplicate URLs: 0
#
# Class distribution:
# Legitimate: 820 (0.51%)
# Phishing: 159244 (99.49%)
#
# Numerical features:
# 11
#
# Categorical features:
# 2
#
# EDA completed successfully!

# %%
# ============================================
# 46. SAVE DATASET COPY
# ============================================

df.to_csv(
    "phishing_urls_eda_dataset.csv",
    index=False
)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!
